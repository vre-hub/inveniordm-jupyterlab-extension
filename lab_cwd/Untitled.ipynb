# %%
from pathlib import Path
Path("~/Library/Jupyter/inveniordm_jupyterlab/tokens.json").expanduser().read_text()
# Out:
# '{"71e5c30a93034dd1817e5a2dd9ae8368": "k1sskKIm7rYqrpIm1rW04iLDv1Jjg8OuAMkOSTAZvBYUBXQTW6L6Z64FtcVF"}'
